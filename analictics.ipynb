# %%
import pandas as pd

# %% [markdown]
# Loading data from data.csv, it is generated with data-grab.ipynb

# %%
data = pd.read_csv('data.csv')

# %%
data
# Out:
#      Unnamed: 0  Job ID                                          Job Title  \
# 0             0   66241             PhD Position – Molecular Neuromedicine
# 1             1   66078  PhD student position in Neuroscience: Object r...
# 2             2   66064  Ph.D. Student : Studying brain circuits involv...
# 3             3   66048       PhD in Behavioral Neuroscience in Copenhagen
# 4             4   65914           PhD student in Experimental Neuroscience
# ..          ...     ...                                                ...
# 250          10    4435                     Ph.D. Student in Essen/Germany
# 251          11    4374                   Ph.D. Student in BORDEAUX/France
# 252          12    4370          Post-doctoral position in BORDEAUX/France
# 253          13    4361                 Ph.D. Student in Magdeburg/Germany
# 254          14    4334  PhD Student Synaptic Molecular Pathology in Co...
#
# ...

# %%
data = data.drop('Unnamed: 0',axis='columns')

# %%
countryAliases = {'The Netherlands': 'Netherlands'}

data["Country"].replace(countryAliases, inplace=True)

# %%
countries = data['Country']
countries.value_counts()
# Out:
# Germany           98
# France            32
# United Kingdom    23
# Italy             14
# Netherlands       12
# Switzerland       11
# Norway            10
# Belgium           10
# Canada            10
# Austria            7
# Israel             6
# Spain              5
# Sweden             5
# Denmark            2
# Ireland            2
# Iceland            1
# Russia             1
# United States      1
# Japan              1
# Portugal           1
# Greece             1
# India              1
# Morocco            1
# Name: Country, dtype: int64
